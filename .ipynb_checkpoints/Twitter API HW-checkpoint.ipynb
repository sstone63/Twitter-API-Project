# %%
import tweepy
import numpy
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

from api_keys import twitter_api, twitter_api_secret, access_token, access_token_secret

# %%
auth = tweepy.OAuthHandler(twitter_api, twitter_api_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_users = ["BBCNews", "@CBSNews", "@CNN", "@FoxNews", "@nytimes"]

results_list = []

tweets_ago = []


for user in target_users:
    
    username = []
    tweet_date = []
    tweet_text = []
    compound_list = []
    positive_list = []
    neutral_list = []
    negative_list = []
    
    
    for x in range(5):
        
        public_tweets = api.user_timeline(user, page=x)
        
        count = 1
        
        for tweet in public_tweets:
            
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            positive = results["pos"]
            neutral = results["neu"]
            negative = results["neg"]
            
            username.append(tweet["user"]["screen_name"])
            tweet_date.append(tweet["created_at"])
            tweet_text.append(tweet["text"])
            compound_list.append(compound)
            positive_list.append(positive)
            neutral_list.append(neutral)
            negative_list.append(negative)
            tweets_ago.append(count)
            
            count += 1
            
news_tweets_df = pd.DataFrame({"Username": username,
                              "Date": tweet_date,
                              "Text": tweet_text,
                              "Compound Score": compound_list,
                              "Positive Score": positive_list,
                              "Neutral Score": neutral_list,
                              "Negative Score": negative_list})

# %%
news_tweets_df.head(20)
# Out:
#     Compound Score                            Date  Negative Score  \
# 0           0.7717  Tue Apr 03 20:27:00 +0000 2018           0.000
# 1           0.0000  Tue Apr 03 20:24:00 +0000 2018           0.000
# 2           0.4588  Tue Apr 03 20:21:00 +0000 2018           0.000
# 3           0.4215  Tue Apr 03 20:18:00 +0000 2018           0.000
# 4           0.0000  Tue Apr 03 20:15:00 +0000 2018           0.000
# 5           0.4588  Tue Apr 03 20:12:00 +0000 2018           0.000
# 6           0.0000  Tue Apr 03 20:09:00 +0000 2018           0.000
# 7           0.0000  Tue Apr 03 20:06:01 +0000 2018           0.000
# 8           0.4939  Tue Apr 03 20:03:07 +0000 2018           0.090
# 9           0.0000  Tue Apr 03 20:00:10 +0000 2018           0.000
# 10          0.3182  Tue Apr 03 19:45:11 +0000 2018           0.000
# 11          0.0000  Tue Apr 03 19:30:09 +0000 2018           0.000
# 12         -0.6808  Tue Apr 03 19:24:04 +0000 2018           0.213
# 13         -0.7579  Tue Apr 03 19:19:10 +0000 2018           0.366
# 14         -0.3818  Tue Apr 03 19:13:43 +0000 2018           0.106
# 15          0.0000  Tue Apr 03 19:00:17 +0000 2018           0.000
# 16          0.5574  Tue Apr 03 18:45:03 +0000 2018           0.000
# 17         -0.4767  Tue Apr 03 18:42:24 +0000 2018           0.171
# 18          0.3612  Tue Apr 03 18:34:12 +0000 2018           0.000
# 19          0.6705  Tue Apr 03 18:30:20 +0000 2018           0.000
#
#     Neutral Score  Positive Score  \
# 0           0.774           0.226
# 1           1.000           0.000
# 2           0.850           0.150
# 3           0.808           0.192
# 4           1.000           0.000
# 5           0.870           0.130
# 6           1.000           0.000
# 7           1.000           0.000
# 8           0.721           0.189
# 9           1.000           0.000
# 10          0.881           0.119
# 11          1.000           0.000
# 12          0.787           0.000
# 13          0.634           0.000
# 14          0.894           0.000
# 15          1.000           0.000
# 16          0.854           0.146
# 17          0.829           0.000
# 18          0.884           0.116
# 19          0.776           0.224
#
#                                                  Text Username
# 0   "Is this America, the land of the free and the...  nytimes
# 1   Diane Nash led students in sit-ins and helped ...  nytimes
# 2   Bernice Johnson Reagon, a leader in the moveme...  nytimes
# 3   Ella Baker convened a landmark meeting at Shaw...  nytimes
# 4   Dorothy Cotton went from administrative assist...  nytimes
# 5   Months before Rosa Parks took her seat on that...  nytimes
# 6   When asked about the role of women in the move...  nytimes
# 7   As president of the National Council of Negro ...  nytimes
# 8   Gloria Richardson, known as Glorious Gloria, f...  nytimes
# 9   The Rev. Dr. Martin Luther King Jr. was assass...  nytimes
# 10  George Wallace's embrace of racial politics te...  nytimes
# 11  Several other countries have modeled their veh...  nytimes
# 12  Elon Musk suggested in a tweet that he's sleep...  nytimes
# 13  RT @arappeport: White House turf battle threat...  nytimes
# 14  In Opinion,\nThe Rev. Jesse Jackson writes, "W...  nytimes
# 15  When President Trump began railing against the...  nytimes
# 16  Many expensive drugs were invented in America ...  nytimes
# 17  The Indian government called the decree a crac...  nytimes
# 18  RT @shailadewan: The Trump administration want...  nytimes
# 19  Meet Samuel Barsky. The knitter has gained fam...  nytimes
